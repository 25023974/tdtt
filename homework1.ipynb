# %% [markdown]
# ## b1

# %%
n = int(input("nhập n:"))
print(n * 2)

# %% [markdown]
# ## b2

# %%
a = float(input("nhập chiều rộng a:"))
b = float(input("nhập chiều dài b:"))
s_hcn = a * b
r = a / 2 
s_tron = 3.14 * (r ** 2)
s_con_lai = s_hcn - s_tron
print(f"{s_con_lai:.2f}")
# Out:
# 121.50

# %% [markdown]
# ## b3

# %%
c = input("Nhập kí tự c: ")
if c.isupper():
    print(f"Chữ thường: {c.lower()}")
    print(f"Chữ hoa: {c.upper()}")
# Out:
# Chữ hoa: A

# %% [markdown]
# ## b4

# %%
c = input("Nhập kí tự c: ")
if c.isalpha():
    print(f"'{c}' là kí tự alphabet")
else:
    print(f"'{c}' không phải là kí tự alphabet")

# %% [markdown]
# ## b5

# %%
A = input("Nhập chữ cái hoa: ")
if A == 'A':
print("z")
else:
prev_char = chr(ord(A.lower()) - 1)
print(prev_char)

# %% [markdown]
# ## b6

# %%
import math
a = float(input("Nhập a: "))
b = float(input("Nhập b: "))
c = float(input("Nhập c: "))

if a + b > c and a + c > b and b + c > a:
    p = (a + b + c) / 2
    s = math.sqrt(p * (p - a) * (p - b) * (p - c))
    print(f"{s:.1f}")
else:
    print("Khong phai 3 canh cua tam giac")
# Out:
# 6.0

# %% [markdown]
# ## b7

# %%
chuoi = input()
if len(chuoi) >= 20:
    print(chuoi[4], chuoi[8])
else:
    print("không phải chuỗi >= 20")
# Out:
# a i

# %%
ten_chu_ho = input("Ten chu ho: ").strip() 
chi_so_cu = int(input("Chi so thang truoc: "))
chi_so_moi = int(input("Chi so thang nay: "))
so_dien = chi_so_moi - chi_so_cu
tien_dien = 0
if so_dien <= 50:
    tien_dien = so_dien * 1984
elif so_dien <= 100:
    tien_dien = (50 * 1984) + ((so_dien - 50) * 2050)
elif so_dien <= 200:
    tien_dien = (50 * 1984) + (50 * 2050) + ((so_dien - 100) * 2380)
elif so_dien <= 300:
    tien_dien = (50 * 1984) + (50 * 2050) + (100 * 2380) + ((so_dien - 200) * 2998)
elif so_dien <= 400:
    tien_dien = (50 * 1984) + (50 * 2050) + (100 * 2380) + (100 * 2998) + ((so_dien - 300) * 3350)
else:
    tien_dien = (50 * 1984) + (50 * 2050) + (100 * 2380) + (100 * 2998) + (100 * 3350) + ((so_dien - 400) * 3460)
tong_tien = tien_dien * 1.08
print(f"Ho va ten: {ten_chu_ho}")
print(f"Tien phai tra la: {round(tong_tien)}")
# Out:
# Ho va ten: 1
# Tien phai tra la: 2143

# %% [markdown]
# ## tự làm bài 2

# %%
a = float(input("chiều rộng"))
b = float(input("chiều dài:"))
s_hcn = a * b
r = a/2 
s_tron = 3.14 * r**2
s_con_lai = s_hcn - s_tron
print("diện tích còn để trồng cây:", f"{s_con_lai:.2f}")
# Out:
# diện tích còn để trồng cây: 121.50

# %% [markdown]
# ## tự làm bài 3

# %%
c = input()
if c.isupper():
    print(c.lower())
elif c.islower():
    print(c.upper())
# Out:
# J

# %% [markdown]
# ## twj b4

# %%
c = input("nhập vào 1 kí tự:")
if c.isalpha():
    print("{c} là kí tự alphabet")
else:
    print("{c} không phải là kí tự alphabet")
# Out:
# {c} là kí tự alphabet

# %% [markdown]
# ## tự làm bài 6

# %%
import math
a = float(input())
b = float(input())
c = float(input())
if (a + b > c) and (a + c > b) and (b + c> a):
    p = (a + b + c) / 2
    dien_tich_tam_giac = math.sqrt(p * (p - a) * (p - b) * (p - c))
    print(f"{dien_tich_tam_giac:.1f}") 
else: 
    print("ko phải 3 cạnh tam giác")
# Out:
# ko phải 3 cạnh tam giác

# %% [markdown]
# ## tự làm bài 7

# %%
chuoi = input("nhập chuỗi gồm các kí tự thường độ dài >= 20")
if len(chuoi) >= 20:
    print(chuoi[4], chuoi[8])
else:
    print("vui lòng nhập chuỗi >= 20")
# Out:
# vui lòng nhập chuỗi >= 20

# %% [markdown]
# ## code luyện thêm ngoài nề

# %%
a = int(input("nhập 1 số nguyên:"))
if (a % 2 == 0):
    print("số chẵn")
else:
    print("số lẻ")
# Out:
# số chẵn

# %%
a = int(input())
if a % 10 == 5:
    print("true")
else:
    print("false")
# Out:
# true

# %%
a = int(input())
if a % 15 == 0:
    print("true")
else:
    print("false")
# Out:
# true

# %%
a = int(input("nhập năm sinh:"))
if 2026 - a >= 18:
    print("đủ tuổi")
else:
    print("k đủ tuổi bầu cử")
# Out:
# k đủ tuổi bầu cử

# %%
a = input()
b = input()
if a > b:
    print(a)
elif a < b:
    print(b)
elif a == b:
    print("2 số bằng nhau")
# Out:
# 10

# %%
ky_tu = input("nhập 1 kí tự")
if ky_tu.isalpha():
    print("đó là chữ cái")
elif ky_tu.isdigit():
    print("đó là số")
else:
    print("không phải chữ và số")
# Out:
# không phải chữ và số

# %%
diem = float(input())
diem = range(0, 11)
if diem >= 8:
    print("giỏi")
    if diem >= 6.5 and diem < 8:
        print("khá")
        if diem >= 5 and diem < 6.5:
            print("trung bình")
        else:
            print("yếu")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[80], line 3
#       1 diem = float(input())
#       2 diem = range(0, 11)
# ----> 3 if diem >= 8:
#       4     print("giỏi")
#       5     if diem >= 6.5 and diem < 8:
#
# TypeError: '>=' not supported between instances of 'range' and 'int'
