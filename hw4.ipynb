# %% [markdown]
# 4a16

# %%
for i in range(3, 100):
    if i % 2 == 0 and i % 3 == 0:
        print(i, end = " ")
# Out:
# 6 12 18 24 30 36 42 48 54 60 66 72 78 84 90 96

# %% [markdown]
# 4a17

# %%
a = int(input())
print(f"bảng cửu chương của {a}:")
for i in range(1, 11):
    bcc = a * i
    print(f"{a} x {i} = {bcc}")
# Out:
# bảng cửu chương của 1:
# 1 x 1 = 1
# 1 x 2 = 2
# 1 x 3 = 3
# 1 x 4 = 4
# 1 x 5 = 5
# 1 x 6 = 6
# 1 x 7 = 7
# 1 x 8 = 8
# 1 x 9 = 9
# 1 x 10 = 10

# %% [markdown]
#  4a18

# %%
a , b = map(int, input().split())
for n in range(1, min(a, b) + 1):
    if a % n == 0 and b % n == 0:
        print(n, end = " ")
# Out:
# 1 2 4 5 10 20 25 50 100

# %% [markdown]
# 4a19

# %%
for n in range(2, 1001, 2):
    print(n, end = " ")
# Out:
# 2 4 6 8

# %% [markdown]
# 4a20

# %%
n = int(input())
copy = n
while copy % 2 == 0:
    copy /= 2
if copy == 1:
    print(f"{n} là 1 số dạng 2^k")
else:
    print("không phải")
# Out:
# 8 là 1 số dạng 2^k

# %% [markdown]
# 4a21

# %%
n = int(input())
copy = n
tong = 0
while copy > 0:
    cs = copy % 10
    tong += cs
    copy //= 10
print(f"tổng các chữ số của {n} = {tong}")
# Out:
# tổng các chữ số của 1239017586327856179421374683279156793250981735 = 217

# %% [markdown]
# 4a22

# %%
n = int(input())
chan = 0 
le = 0
copy = n
while copy > 0:
    cs = copy % 10
    if cs % 2 == 0:
        chan += 1
    else:
        le += 1
    copy //= 10
print(f"{n} có {chan} cso chẵn và {le} cso lẻ")
# Out:
# 123456789 có 4 cso chẵn và 5 cso lẻ

# %% [markdown]
# 4a23

# %%
n = int(input())
s = 0
k = 0
while s + (k + 1) < n:
    k += 1
    s += k
print(f"k = {k} cho s(k) lớn nhất = {s}")
# Out:
# k = 3 cho s(k) lớn nhất = 6

# %% [markdown]
# 4a24

# %%
A = int(input())
tong = 0
n = 0
while s <= A:
    n += 1
    s += 1/n
print(f"n nhỏ nhất = {n} để tman dkien")
# Out:
# n nhỏ nhất = 31 để tman dkien

# %% [markdown]
# 4a25

# %%
a = int(input())
if a == -1:
    print("k thể so sánh ")
else:
    max_a = a
    min_a = a
    while True:
        b = int(input())
        if b == -1:
            break
        elif b > max_a:
            max_a = b
        elif b < min_a:
            min_a = b
    print(f"{min_a},{max_a}")
# Out:
# k thể so sánh

# %% [markdown]
# 4a26

# %%
A = int(input("Nhập số nguyên dương A: "))
f1 = 1
f2 = 1
if A < 1:
    print("Không có số Fibonacci nào thỏa mãn.")
else:
    dapan = 1 
    while True:
        f_next = f1 + f2 
        if f_next > A:
            dapan = f2 
            break
        f1 = f2
        f2 = f_next
    print(f"Số Fibonacci lớn nhất không vượt quá {A} là: {dapan}")
# Out:
# Số Fibonacci lớn nhất không vượt quá 50 là: 34

# %% [markdown]
# 4a27

# %%
n = input("chỉ nhập chữ và khoảng trắng")
sotu = 0
dag_o_trong_tu = False
for i, char in enumerate(n):
    if char != " ":
        if not dag_o_trong_tu:
            sotu += 1
            dag_o_trong_tu = True
    else:
        dag_o_trong_tu = False
print(f"số từ  trong chuỗi là {sotu}")
# Out:
# số từ  trong chuỗi là 7

# %% [markdown]
# 4a28

# %%
a = input("nhập 1 chuỗi")
tudautien = " "
for i, char in enumerate(a):
    if char != " ":
        tudautien += char
    else:
        if tudautien != " ":
            break
print(f"từ đầu tiên là {tudautien}")
# Out:
# từ đầu tiên là  vybeo

# %% [markdown]
# 4a29

# %%
s = input("Nhập chuỗi: ")
chuoi_moi = ""
for char in s:
    if char.islower():
        chuoi_moi += char.upper() 
    elif char.isupper():
        chuoi_moi += char.lower() 
    else:
        chuoi_moi += char 
print(f"Chuỗi sau khi đổi: {chuoi_moi}")
# Out:
# Chuỗi sau khi đổi: ÁIDAISJODIAOJSDIJAD

# %% [markdown]
# 4a30

# %%
a = input("Nhập: ")
danh_sach_so = a.split(',')
tong = int(danh_sach_so[0]) + int(danh_sach_so[1]) + int(danh_sach_so[2])
print(f"Tổng: {tong}")
# Out:
# Tổng: 30

# %% [markdown]
# 4a31

# %%
s = input("Nhập chuỗi: ")
in_hoa = 0
in_thuong = 0
chữ_so = 0
for char in s:
    if char.isupper():
        in_hoa += 1
    elif char.islower():
        in_thuong += 1
    elif char.isdigit():
        chữ_so += 1
print(f"Ký tự in hoa: {in_hoa}")
print(f"Ký tự in thường: {in_thuong}")
print(f"Ký tự số: {chữ_so}")
# Out:
# Ký tự in hoa: 1
# Ký tự in thường: 3
# Ký tự số: 3
